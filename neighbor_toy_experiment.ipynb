# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
time_step = 100
input_num = 500
adjust_steps = 1000

tau_i_input = 3 * np.ones(input_num)
tau_i_output = 3
tau_u = 10

i_input_decay = (1-1/tau_i_input)
i_output_decay = (1-1/tau_i_output)
u_decay = (1-1/tau_u)

# %%
def smooth(x, decay):
    if len(x.shape)==1:
        x = x.reshape(1,len(x))
    x = x.astype(float)
    x_smooth = np.zeros_like(x)
    x_smooth[:,0]=x[:,0]/(1/(1-decay))
    for i in range(len(x[0])-1):
        x_smooth[:,i+1] = x_smooth[:,i]*decay + x[:,i+1].astype(float)/(1/(1-decay))
    return x_smooth

# %%
def sigmoid(x,temp):
    exp = np.clip(-x/temp, -10, 10)
    return 1 / (1 + np.exp(exp))

# %%
output_record = np.zeros((adjust_steps, time_step))
delta_0_record = np.zeros((adjust_steps, time_step))
delta_record = np.zeros((adjust_steps, time_step))
grad_record = np.zeros((adjust_steps, time_step))

loss_record = np.zeros(adjust_steps)
tau_u_record = np.zeros(adjust_steps)
i_decay_record = np.zeros(adjust_steps)
u = np.zeros(time_step)
delta_u = np.zeros(time_step)
output = np.zeros(time_step)

# %%
def gen_partial_a(delta):
    partial_a = np.zeros((time_step, time_step))
    for t in range(time_step):
        if t > 0:
            partial_a[t] = partial_a[t - 1] - partial_a[t - 1] / tau_i_output
        partial_a[t, t] = 1/tau_i_output
    for t in range(time_step):
        if delta[t] <= 0:
#             partial_a[t-1, t] = -1
#             for j in range(t-2,-1,-1):
#                 partial_a[j,t] = partial_a[j+1,t] * (1 - 1 / tau_i_output)
            partial_a[t, t] = 0
        else:
            partial_a[t, t] = -1
    return partial_a
    
partial_a_0 = np.zeros((time_step, time_step))
for t in range(time_step):
    if t > 0:
        partial_a_0[t] = partial_a_0[t - 1] - partial_a_0[t - 1] / tau_i_output
    partial_a_0[t, t] = 1/tau_i_output

# %%
def figs_plot(plot_flag):
    if plot_flag:
        plt.figure()
        plt.plot(loss_record)
        
        plt.figure(figsize=(12,5*adjust_steps/time_step/2))

        plt.subplot(141)
        plt.imshow(output_record, cmap='cividis')
        plt.title('output record')
        for i,o in enumerate(desired_output[0]):
            if o == 1:
                plt.plot((i,i),(0,adjust_steps-1),c='r',alpha=.2)
        plt.colorbar()
    #     plt.figure(figsize=(5,5*adjust_steps/time_step))
        plt.subplot(142)
        plt.imshow(delta_0_record, cmap='cividis')
        plt.title('delta_0_record')
        for i,o in enumerate(desired_output[0]):
            if o == 1:
                plt.plot((i,i),(0,adjust_steps-1),c='r',alpha=.2)
        plt.colorbar()

    #     plt.figure(figsize=(5,5*adjust_steps/time_step))
        plt.subplot(143)
        plt.imshow(delta_record, cmap='cividis')
        plt.title('delta_record')
        for i,o in enumerate(desired_output[0]):
            if o == 1:
                plt.plot((i,i),(0,adjust_steps-1),c='r',alpha=.2)
        plt.colorbar()
                
        plt.subplot(144)
        plt.imshow(grad_record, cmap='cividis')
        plt.title('grad_record')
        for i,o in enumerate(desired_output[0]):
            if o == 1:
                plt.plot((i,i),(0,adjust_steps-1),c='r',alpha=.2)
        plt.colorbar()
def prepare_plot(plot_flag):
    if plot_flag:
        plt.figure(figsize=(6,4))
        global u_fig
        u_fig = plt.axes()
        plt.title("Membrane Potential")
        
        plt.figure(figsize=(6,4))
        global delta_u_fig
        delta_u_fig = plt.axes()
        plt.title('delta_u')
        
        plt.figure(figsize=(6,4))
        global timing_grad_fig
        timing_grad_fig = plt.axes()
        plt.title('timing_grad')
        
        plt.figure(figsize=(6,4))
        global new_grad_fig
        new_grad_fig = plt.axes()
        plt.title('new_grad_fig')
        
        plt.figure(figsize=(6,4))
        global delta_fig
        delta_fig = plt.axes()
        plt.title('Delta')

        plt.figure(figsize=(6,4))
        global grad_fig
        grad_fig = plt.axes()
        plt.title('Grad')

# %%
threshold = 1

temp = 0.2

# %%
a = np.random.randint(0,30, size=(input_num,time_step))
a = (a==0).astype(float)
a_smooth = smooth(a, i_input_decay)
plt.figure(figsize=(6,4))
plt.imshow(a_smooth, cmap='cividis')
plt.colorbar(shrink=.5)

# %%
weights = (np.random.random(size=input_num)-0.2) *0.1
desired_output = np.random.randint(0,20,size=(1,time_step))
desired_output = (desired_output == 0).astype(float)
plt.figure()
output_fig = plt.axes()
desired_output_smooth = smooth(desired_output, i_output_decay)
output_fig.plot(desired_output_smooth[0])

# If plot needed, set plot_flag = True
plot_flag = True
prepare_plot(plot_flag)

tau_i_input = 3 * np.ones(input_num)
tau_i_output = 3
tau_u = 10

i_input_decay = (1-1/tau_i_input)
i_output_decay = (1-1/tau_i_output)
u_decay = (1-1/tau_u)
lr = 0.005
for i in range(adjust_steps):
    lr *= 0.996
    # Forward
    output = np.zeros(time_step)
    u[0] = delta_u[0] = u_temp = np.dot(weights, a_smooth[:,0])
    
    if u[0] > threshold:
        u_temp = 0
        output[0] = 1
    for j in range(time_step-1):
        u[j+1] = u_temp * u_decay + np.dot(weights,a_smooth[:,j+1])
        delta_u[j+1] = u[j+1] - u[j]
        if u[j+1] > threshold:
            u_temp = 0
            output[j+1] = 1
        else:
            u_temp = u[j+1]
    output_smooth = smooth(output, i_output_decay)
    output_fig.plot(output_smooth[0])
    
    # Record status
    output_record[i] = output
#     output_smooth_record[i] = output_smooth
#     u_record[i] = u
    
    # Backward
    # Calculate weight's gradient
    delta_0 = (output_smooth-desired_output_smooth)[0]
    delta_0_record[i] = delta_0
    
    partial_a = gen_partial_a(delta_0)
    delta = delta_0.dot(partial_a)
    delta_record[i] = delta
     
    loss_record[i] = np.sum((output_smooth-desired_output_smooth)[0]**2)
    sig = sigmoid(u-threshold, temp)
    grad = delta_0.dot(partial_a_0)*(sig*(1-sig))/temp
    for g in range(len(grad)-2, -1, -1):
        grad[g] += grad[g+1] * u_decay * (1 - output[g])
    grad_w = grad.dot(a_smooth.T)
    timing_grad = np.clip((-1/np.array(delta_u)), -0.5, 0) * output
    new_grad = delta * timing_grad * sig
    new_grad_w = new_grad.dot(a_smooth.T)
    
    grad_record[i] = grad + new_grad

    if plot_flag:
        u_fig.plot(u)
        delta_u_fig.plot(delta_u)
        timing_grad_fig.plot(timing_grad)
        new_grad_fig.plot(new_grad)
        delta_fig.plot(delta)
        grad_fig.plot(grad)
    
    # Move Step
    weights = weights - lr * (grad_w + new_grad_w)
figs_plot(plot_flag)

# %%
0.996**1000
# Out:
# 0.018169309535589467

# %%
plt.figure()
grad = delta_0.dot(partial_a_0)*(sig*(1-sig))/temp
plt.plot(grad)
for g in range(len(grad)-2, -1, -1):
    grad[g] += grad[g+1] * u_decay * (1-output[g])
plt.plot(grad)

plt.figure()
plt.plot(delta_0)

# %%
plt.plot(delta)
plt.figure()
plt.plot(output_smooth[0])
plt.plot(desired_output_smooth[0])
plt.figure(figsize = (10,10))
plt.imshow(partial_a)
plt.colorbar()
print()

# %%
tau_i_output = 20
def gen_partial_a(delta):
    partial_a = np.zeros((time_step, time_step))
    for t in range(time_step):
        if t > 0:
            partial_a[t] = partial_a[t - 1] - partial_a[t - 1] / tau_i_output
        partial_a[t, t] = 1/tau_i_output
    for t in range(time_step):
        if delta[t] <= 0:
            partial_a[t-1, t] = -partial_a[t, t]
            partial_a[t, t] = 0
        else:
            partial_a[t, t] = -partial_a[t, t]   
    return partial_a
partial_a = gen_partial_a(delta)
plt.imshow(partial_a)
print(partial_a)
# Out:
# [[-0.05       -0.05        0.         ...  0.          0.
#    0.        ]
#  [ 0.0475      0.         -0.05       ...  0.          0.
#    0.        ]
#  [ 0.045125    0.0475      0.         ...  0.          0.
#    0.        ]
#  ...
#  [ 0.00034527  0.00036344  0.00038257 ... -0.05        0.
#    0.        ]
#  [ 0.00032801  0.00034527  0.00036344 ...  0.0475     -0.05
#    0.        ]
#  [ 0.00031161  0.00032801  0.00034527 ...  0.045125    0.0475
#   -0.05      ]]

# %%
plt.plot(output_smooth_record[180]-desired_output_smooth[0])
